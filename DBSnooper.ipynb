# %% [markdown]
# # DBSnooper
# ### By: Alex Perez
#
# ---------------

# %% [markdown]
# ## Introduction
# This notebook will be used to generate a Quick report on Exposed Database's globally. For demonstration purposes, we will use ElasticSearch Database Instances.
#
# ## Versioning:
# * 1.0: Initial Draft
# * 1.1: Includes an Interactive Map

# %%
# Custom Function that was built to Interact with Shodan
from src.ShodanUtils import Shodan
from src.VisualizationUtils import ShodanMap

# %% [markdown]
# # The Dataframe of the Results:
# ---------

# %%
# Elastic Databases Search
Elastic_Database_Search = Shodan.Shodan_Search(
    searchTerm="Elastic"
    )

# This will display the Dataframe with all of the results in an organized Table
display(Elastic_Database_Search)
# Out:
#             ip_str  port                                                org  \
# 0    18.219.36.201  9200                           Amazon Technologies Inc.
# 1    34.90.122.198    80                                         Google LLC
# 2   52.220.236.204  9200                     Amazon Data Services Singapore
# 3      139.9.68.66  9200  Huawei Public Cloud Service (Huawei Software T...
# 4     34.64.219.23  9200                      Google Asia Pacific Pte. Ltd.
# ..             ...   ...                                                ...
# 95    83.96.214.42  9200                                      ProServe B.V.
# 96    68.79.30.129    80         Ningxia West Cloud Data Technology Co.Ltd.
# 97  34.201.109.125  9200                           Amazon Technologies Inc.
# 98    44.235.217.9  9200                                   Amazon.com, Inc.
# 99  78.129.161.109  9200                                            Dx3webs
#
#          asn                                         isp  product  \
# 0    AS16509                            Amazon.com, Inc.  Elastic
# 1    AS15169                                  Google LLC      NaN
# 2    AS16509                            Amazon.com, Inc.  Elastic
# 3    AS55990            Huawei Cloud Service data center  Elastic
# 4   AS139070               Google Asia Pacific Pte. Ltd.  Elastic
# ..       ...                                         ...      ...
# 95   AS35470                                 Signet B.V.  Elastic
# 96  AS135629  Ningxia West Cloud Data Technology Co.Ltd.  Elastic
# 97   AS14618                            Amazon.com, Inc.  Elastic
# 98   AS16509                            Amazon.com, Inc.  Elastic
# 99   AS20860               IOMART CLOUD SERVICES LIMITED  Elastic
#
#    location.country_name  location.latitude  location.longitude
# 0          United States           40.03340           -83.15825
# 1            Netherlands           53.21917             6.56667
# 2              Singapore            1.28967           103.85007
# 3                  China           23.11667           113.25000
# 4     Korea, Republic of           37.56600           126.97840
# ..                   ...                ...                 ...
# 95           Netherlands           52.37403             4.88969
# 96                 China           38.46806           106.27306
# 97         United States           39.04372           -77.48749
# 98         United States           45.83986          -119.70058
# 99        United Kingdom           51.50853            -0.12574
#
# [100 rows x 9 columns]

# %% [markdown]
# # Interactive Map:
# -----------------

# %%
# Building the Interactive Map with the Data
ShodanMap.BuildMap(
    Dataframe=Elastic_Database_Search,
    latitude_column='location.latitude',
    longitude_column='location.longitude'
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Top 10 Organizations
# ---------------
